# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import re
import string 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier,RidgeClassifier,PassiveAggressiveClassifier
import pickle
from sklearn.metrics import precision_recall_fscore_support,accuracy_score, classification_report
from sklearn.calibration import CalibratedClassifierCV,_CalibratedClassifier
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from pprint import pprint
from time import time
import logging
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# # Define Constants

# %%
data_filepath = "it_dec18_mod.csv"
label_freq_threshold = 10

# requirement for new data

cols = ['Resolution','Subject','body','ActualService']
training_cols = ['Resolution','Subject','body']
runtime_cols = ['Subject','body']
target_col = ['ActualService']

#internal declaration

train_col_name = "train_text"
val_col_name = "val_text"

# %% [markdown]
# # Data Preprocessing

# %%
def remove_and_dedup_punctuation_numbers(text): 
    result = re.sub('<.*?>', '', text.replace("(AutoClosed)","").replace("\n","").replace("\r","")\
                    .replace("&nbsp;","").replace("***",""))
    result = result.replace('[\w\d\.-]+@[\w\d\.-]+',' ').replace(
    '\d+', ' ').replace('_+', ' ').replace('+', ' ').replace(
    '.', ' ').replace('^https?:\/\/.*[\r\n]*', '').replace('[^\w]',' ').lower()
    result = re.sub (r'([^a-zA-Z\s.?!])', '', result)
    result = re.sub(r"([" + re.escape(string.punctuation) + r"])\1+", r"\1", result)
    result = re.sub( '\s+', ' ', result ).strip()
    return result


def drop_nan(df,training_cols,target_col):
    print("method drop_nan started:\n")
    print("number of records before processing: ",df.__len__())
    df1 = df[training_cols].dropna(how="all")
    indices_1 = df1.index
    df2 = df[target_col].dropna(how="all")
    indices_2 = df2.index
    indices_final = list(set.intersection(set(indices_1),set(indices_2)))
    return_df = df.iloc[indices_final][training_cols+target_col]
    print("number of records after processing: ",return_df.__len__())
    print("NaN value Present? ",return_df[target_col+training_cols].isnull().values.any())
    return_df.fillna("", inplace=True)
    print("NaN value Present? ",return_df[target_col+training_cols].isnull().values.any())
    print("\nmethod drop_nan ended.\n\n")
    return return_df

def create_and_clean_train_test_target_column(df):
    print("method create_and_clean_train_test_target_column started:\n")
    df[train_col_name] = df[training_cols].apply(lambda x: " ".join(x), axis=1)
    df[train_col_name] = df[train_col_name].map(remove_and_dedup_punctuation_numbers)
    df[val_col_name] = df[runtime_cols].apply(lambda x: " ".join(x), axis=1)
    df[val_col_name] = df[val_col_name].map(remove_and_dedup_punctuation_numbers)
    print("\nmethod create_and_clean_train_test_target_column ended.\n\n")
    return df[[train_col_name,val_col_name]+target_col]

# %% [markdown]
# # Modeling

# %%
def encode_decision(y):
    encoder= LabelEncoder()
    y = y.ravel()
    encoder.fit(y)
    y_encoded=encoder.transform(y)
    return y_encoded,encoder


def get_tfidf_parameters():
    param =  {
        'tfidf__lowercase':(True,),
        'tfidf__stop_words':('english',),
        'tfidf__max_df': (0.90,0.85),
        'tfidf__min_df': (2,5),
        'tfidf__sublinear_tf': (True,),
        'tfidf__ngram_range': ((1,3),)
    }
    return param

def get_SGDClassifier_parameters():
    param = {
        'clf__alpha': (0.0001,),
        'clf__penalty': ('elasticnet',),
        'clf__loss': ('hinge',),
        'clf__max_iter': (20,)
    }
    return param

def get_RidgeClassifier_parameters():
    param = {
        'clf__tol': (1e-2,),
        'clf__solver': ('sag',)
    }
    return param


def get_LinearSVC_parameters():
    param = {
        'clf__penalty': ('l2',),
        'clf__loss': ('hinge',),
        'clf__tol': (1e-4,),
        'clf__max_iter': (10,),
        'clf__multi_class': ('ovr',),
        'clf__class_weight': ('balanced',)
    }
    return param


def get_RandomForestClassifier_parameters():
    param = {
        'clf__n_estimators': (90,),
        'clf__max_depth': (11,),
        'clf__min_samples_leaf': (8,)
    }
    return param

def get_LogisticRegression_parameters():
    param = {
        'clf__multi_class': ('ovr',),
    }
    return param

def get_PassiveAggressiveClassifier_parameters():
    param = {
        'clf__max_iter': (50,),
    }
    return param

def print_model_stat(grid_search,pipeline,parameters,clfname):
    print("Performing grid search for ",clfname," ...")
    print("pipeline:", [name for name, _ in pipeline.steps])
    print("parameters:")
    pprint(parameters)    
    print()
    print("Best score: %0.3f" % grid_search.best_score_)
    print()
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
        
def get_clf_and_parameter(clfname):
    if clfname == "SGDClassifier":
        clf = SGDClassifier()
        clf_param = get_SGDClassifier_parameters()
    elif clfname == "RidgeClassifier":
        clf = RidgeClassifier()
        clf_param = get_RidgeClassifier_parameters()
    elif clfname == "LinearSVC":
        clf = LinearSVC()
        clf_param = get_LinearSVC_parameters()
    elif clfname == "RandomForestClassifier":
        clf = RandomForestClassifier()
        clf_param = get_RandomForestClassifier_parameters()
    elif clfname == "LogisticRegression":
        clf = LogisticRegression()
        clf_param = get_LogisticRegression_parameters()
    elif clfname == "PassiveAggressiveClassifier":
        clf = PassiveAggressiveClassifier()
        clf_param = get_PassiveAggressiveClassifier_parameters()
    else:
        raise BaseException("Unknown Classifier.")
        
    return clf,clf_param
        
def train_gridsearch_classifier_pipeline(train_df,clfname,val_col_name,target_col,score = 'accuracy'):
    
    clf,clf_param = get_clf_and_parameter(clfname)
        
    pipeline = Pipeline([
        ('tfidf', TfidfVectorizer()),
        ('clf', clf)])
    
    tfidf_param = get_tfidf_parameters()
    
    parameters = {**tfidf_param, **clf_param}
    
    grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1,scoring=score)
    X = train_df[val_col_name].as_matrix()
    Y = train_df[target_col].as_matrix().ravel()
    grid_search.fit(X, Y)
    
    print_model_stat(grid_search,pipeline,parameters,clfname)
    
    #https://github.com/scikit-learn/scikit-learn/issues/8710
    calibrated_pipeline = _CalibratedClassifier(base_estimator=grid_search.best_estimator_, method='isotonic')
    return calibrated_pipeline



class ServicePredictionModel(object):
    def __init__(self,best_model,best_acc,best_classifier_name):
        self.best_model = best_model
        self.best_cv_acc = best_acc
        self.best_classifier_name = best_classifier_name
    
    @classmethod
    def train(cls,df,target_col,train_col_name,val_col_name):
        target = df[target_col].as_matrix()
        train_df, test_df = train_test_split(df,test_size=0.2,stratify=target,random_state=0)
        
        classifier_names = [
                            "LogisticRegression",
                            "RandomForestClassifier",
                            "LinearSVC",
                            "SGDClassifier",
                            "RidgeClassifier",
                            "PassiveAggressiveClassifier"
                           ]
        classifiers = list()
        
        for classifier_name in classifier_names:
            classifier = train_gridsearch_classifier_pipeline(train_df,classifier_name,
                                                              val_col_name,target_col)
            classifiers.append(classifier)
                
        best_model = None
        best_cv_acc = -100
        best_classifier_name = None
        
        X = train_df[train_col_name].as_matrix()
        Y = train_df[target_col].as_matrix().ravel()
        
        for i,clf in enumerate(classifiers):
            
            clf.fit(X,Y)
            label_encoder = clf.label_encoder_
            Y_prob = clf.predict_proba(test_df[val_col_name])
            Y_index = np.argmax(Y_prob,axis=1)
            Y_index = Y_index.ravel()
            # https://github.com/scikit-learn/scikit-learn/issues/10449
            Y_pred = label_encoder.inverse_transform(Y_index)
            Y_test = test_df[target_col]
            cv_acc = accuracy_score(Y_test, Y_pred)
            if cv_acc > best_cv_acc:
                best_cv_acc = cv_acc
                best_model = clf
                best_classifier_name = classifier_names[i]
            print("Classifier Name : ",classifier_names[i])
            print("Validation Accuracy : ",cv_acc)
            
        X = df[train_col_name].as_matrix()
        Y = df[target_col].as_matrix().ravel()
            
        best_model.fit(X,Y)
        
        print("Best classifier Name : ",best_classifier_name)
        print("Best validation Accuracy : ",best_cv_acc)
            
        return ServicePredictionModel(best_model,best_cv_acc,best_classifier_name)


    
    def save(self,filepath):
        model_dict = {"model":self.best_model,
                      "validation_accuracy":self.best_cv_acc,
                      "model_name":self.best_classifier_name
                     }
        with open(filepath,"wb") as fp:
            pickle.dump(model_dict,fp,pickle.HIGHEST_PROTOCOL)

# %%
def preprocess_data(data_filepath):
    df = pd.read_csv(data_filepath,low_memory=False)
    truncated_df_null_removed = drop_nan(df,training_cols,target_col)
    df_train_test_target = create_and_clean_train_test_target_column(truncated_df_null_removed)
    df_cleaned = df_train_test_target.groupby(target_col).filter(lambda x: len(x) > label_freq_threshold)
    return df_cleaned
    
def train_and_save_model(df_cleaned,target_col,train_col_name,val_col_name):
    service_pred_model = ServicePredictionModel.train(df_cleaned,target_col,train_col_name,val_col_name)
    service_pred_model.save("./service_model.pkl")

# %%
def main():
    df_cleaned = preprocess_data(data_filepath)
    train_and_save_model(df_cleaned,target_col,train_col_name,val_col_name)

# %%
# %%time

if __name__ == "__main__":
    main()
# Out:
# method drop_nan started:
#
# number of records before processing:  31932
# number of records after processing:  31739
# NaN value Present?  True
# NaN value Present?  False
#
# method drop_nan ended.
#
#
# method create_and_clean_train_test_target_column started:
#
#
# method create_and_clean_train_test_target_column ended.
#
#
# Performing grid search for  LogisticRegression  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__multi_class': ('ovr',),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.684
#
# Best parameters set:
# 	clf__multi_class: 'ovr'
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 5
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  RandomForestClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__max_depth': (11,),
#  'clf__min_samples_leaf': (8,),
#  'clf__n_estimators': (90,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.655
#
# Best parameters set:
# 	clf__max_depth: 11
# 	clf__min_samples_leaf: 8
# 	clf__n_estimators: 90
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 5
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  LinearSVC  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__class_weight': ('balanced',),
#  'clf__loss': ('hinge',),
#  'clf__max_iter': (10,),
#  'clf__multi_class': ('ovr',),
#  'clf__penalty': ('l2',),
#  'clf__tol': (0.0001,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.396
#
# Best parameters set:
# 	clf__class_weight: 'balanced'
# 	clf__loss: 'hinge'
# 	clf__max_iter: 10
# 	clf__multi_class: 'ovr'
# 	clf__penalty: 'l2'
# 	clf__tol: 0.0001
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 2
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  SGDClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__alpha': (0.0001,),
#  'clf__loss': ('hinge',),
#  'clf__max_iter': (20,),
#  'clf__penalty': ('elasticnet',),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.688
#
# Best parameters set:
# 	clf__alpha: 0.0001
# 	clf__loss: 'hinge'
# 	clf__max_iter: 20
# 	clf__penalty: 'elasticnet'
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 5
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  RidgeClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__solver': ('sag',),
#  'clf__tol': (0.01,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.694
#
# Best parameters set:
# 	clf__solver: 'sag'
# 	clf__tol: 0.01
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.85
# 	tfidf__min_df: 2
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  PassiveAggressiveClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__max_iter': (50,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.647
#
# Best parameters set:
# 	clf__max_iter: 50
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 2
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  LogisticRegression
# Validation Accuracy :  0.6853808547547705
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  RandomForestClassifier
# Validation Accuracy :  0.6760763286547863
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  LinearSVC
# Validation Accuracy :  0.673079955842927
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  SGDClassifier
# Validation Accuracy :  0.6869578930768018
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  RidgeClassifier
# Validation Accuracy :  0.6830152972717237
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  PassiveAggressiveClassifier
# Validation Accuracy :  0.642170004731115
# Best classifier Name :  SGDClassifier
# Best validation Accuracy :  0.6869578930768018
# CPU times: user 1min 40s, sys: 3.02 s, total: 1min 43s
# Wall time: 5min 28s

# %%
model_dict = joblib.load("service_model.pkl")

# %%
clf = model_dict["model"]
df_cleaned = preprocess_data(data_filepath)
target = df_cleaned[target_col].as_matrix()
train_df, test_df = train_test_split(df_cleaned,test_size=0.2,stratify=target,random_state=0)
label_encoder = clf.label_encoder_
Y_prob = clf.predict_proba(test_df[val_col_name])
Y_index = np.argmax(Y_prob,axis=1)
Y_index = Y_index.ravel()
# https://github.com/scikit-learn/scikit-learn/issues/10449
Y_pred = label_encoder.inverse_transform(Y_index)
Y_test = test_df[target_col]
# Out:
# method drop_nan started:
#
# number of records before processing:  31932
# number of records after processing:  31739
# NaN value Present?  True
# NaN value Present?  False
#
# method drop_nan ended.
#
#
# method create_and_clean_train_test_target_column started:
#
#
# method create_and_clean_train_test_target_column ended.
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.6931083425327236

# %%
conf = pd.crosstab(Y_test.ActualService, Y_pred)
classification = classification_report(Y_test, Y_pred)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(classification)
# Out:
#                                  precision    recall  f1-score   support
#
# Application Development Service       0.59      0.61      0.60       585
#              Audio Conferencing       0.00      0.00      0.00         2
#                       BitLocker       0.36      0.24      0.29        17
#      Business Analytics Service       0.45      0.35      0.39        37
#         Communications Services       0.15      0.06      0.08        72
#                    Data Service       0.00      0.00      0.00        16
#                 Desktop Service       0.50      0.02      0.04       171
#                Domain Migration       0.73      0.63      0.68        35
#                   Email Service       0.40      0.06      0.11       124
#         Employee Administration       0.63      0.42      0.50       100
#  Enterprise Application Service       0.00      0.00      0.00        70
#           Facilities Management       0.50      0.17      0.25        12
#               Financial Service       0.00      0.00      0.00         4
#                   Global DevOps       0.27      0.17      0.21        54
#       IT General Administration       0.34      0.05      0.09       213
#            Integration Services       0.68      0.57      0.62        23
#                     Ivanti 100%       0.00      0.00      0.00        34
#                Licensing Portal       0.37      0.30      0.33        23
#                    Mail Service       0.00      0.00      0.00        42
#            Mobile Communication       0.60      0.26      0.36        23
#                 Network Service       0.36      0.10      0.16       119
#                            OKTA       0.12      0.03      0.05        34
#                            OSUI       0.55      0.86      0.67         7
#                Printing Service       0.20      0.10      0.13        10
#             Sales and Marketing       0.71      0.68      0.70        44
#           Server Administration       0.42      0.38      0.40       283
#                    Service Desk       0.74      0.90      0.81      4135
#                Web Conferencing       0.67      0.06      0.11        32
#                           WebEx       0.50      0.05      0.09        20
#
#                     avg / total       0.63      0.69      0.64      6341

# %%
conf
# Out:
# col_0                            Application Development Service  BitLocker  \
# ActualService
# Application Development Service                              355          0
# Audio Conferencing                                             0          0
# BitLocker                                                      0          4
# Business Analytics Service                                    14          0
# Communications Services                                        3          0
# Data Service                                                   1          0
# Desktop Service                                                3          0
# Domain Migration                                               0          0
# Email Service                                                  4          0
# Employee Administration                                       14          0
# Enterprise Application Service                                13          0
# Facilities Management                                          0          0
# Financial Service                                              1          0
# Global DevOps                                                  1          0
# IT General Administration                                     16          0
# Integration Services                                           5          0
# Ivanti 100%                                                    0          0
# Licensing Portal                                               1          0
# Mail Service                                                   1          0
# Mobile Communication                                           0          0
# Network Service                                                1          0
# OKTA                                                           1          0
# OSUI                                                           0          0
# Printing Service                                               0          0
# Sales and Marketing                                            2          0
# Server Administration                                          3          0
# Service Desk                                                 166          7
# Web Conferencing                                               0          0
# WebEx                                                          0          0
#
# col_0                            Business Analytics Service  \
# ActualService
# Application Development Service                           7
# Audio Conferencing                                        0
# BitLocker                                                 0
# Business Analytics Service                               13
# Communications Services                                   0
# Data Service                                              0
# Desktop Service                                           0
# Domain Migration                                          0
# Email Service                                             0
# Employee Administration                                   0
# Enterprise Application Service                            1
# Facilities Management                                     0
# Financial Service                                         0
# Global DevOps                                             0
# IT General Administration                                 0
# Integration Services                                      0
# Ivanti 100%                                               0
# Licensing Portal                                          0
# Mail Service                                              0
# Mobile Communication                                      0
# Network Service                                           0
# OKTA                                                      0
# OSUI                                                      0
# Printing Service                                          0
# Sales and Marketing                                       0
# Server Administration                                     0
# Service Desk                                              8
# Web Conferencing                                          0
# WebEx                                                     0
#
# col_0                            Communications Services  Desktop Service  \
# ActualService
# Application Development Service                        1                0
# Audio Conferencing                                     0                0
# BitLocker                                              0                0
# Business Analytics Service                             0                0
# Communications Services                                4                0
# Data Service                                           0                0
# Desktop Service                                        1                4
# Domain Migration                                       0                0
# Email Service                                          0                0
# Employee Administration                                0                0
# Enterprise Application Service                         0                0
# Facilities Management                                  0                0
# Financial Service                                      0                0
# Global DevOps                                          0                0
# IT General Administration                              3                0
# Integration Services                                   0                0
# Ivanti 100%                                            0                0
# Licensing Portal                                       0                0
# Mail Service                                           0                0
# Mobile Communication                                   0                0
# Network Service                                        1                0
# OKTA                                                   0                0
# OSUI                                                   0                0
# Printing Service                                       0                0
# Sales and Marketing                                    0                0
# Server Administration                                  4                1
# Service Desk                                          12                3
# Web Conferencing                                       0                0
# WebEx                                                  0                0
#
# col_0                            Domain Migration  Email Service  \
# ActualService
# Application Development Service                 2              1
# Audio Conferencing                              0              0
# BitLocker                                       0              0
# Business Analytics Service                      0              0
# Communications Services                         0              0
# Data Service                                    0              0
# Desktop Service                                 0              1
# Domain Migration                               22              0
# Email Service                                   0              8
# Employee Administration                         0              0
# Enterprise Application Service                  0              0
# Facilities Management                           0              0
# Financial Service                               0              0
# Global DevOps                                   0              0
# IT General Administration                       0              1
# Integration Services                            0              0
# Ivanti 100%                                     0              0
# Licensing Portal                                0              0
# Mail Service                                    0              0
# Mobile Communication                            0              0
# Network Service                                 0              0
# OKTA                                            0              0
# OSUI                                            0              0
# Printing Service                                0              0
# Sales and Marketing                             0              0
# Server Administration                           1              1
# Service Desk                                    5              8
# Web Conferencing                                0              0
# WebEx                                           0              0
#
# col_0                            Employee Administration  \
# ActualService
# Application Development Service                        1
# Audio Conferencing                                     0
# BitLocker                                              0
# Business Analytics Service                             0
# Communications Services                                0
# Data Service                                           0
# Desktop Service                                        0
# Domain Migration                                       0
# Email Service                                          0
# Employee Administration                               42
# Enterprise Application Service                         0
# Facilities Management                                  0
# Financial Service                                      0
# Global DevOps                                          0
# IT General Administration                              0
# Integration Services                                   0
# Ivanti 100%                                            0
# Licensing Portal                                       0
# Mail Service                                           0
# Mobile Communication                                   0
# Network Service                                        1
# OKTA                                                   0
# OSUI                                                   0
# Printing Service                                       0
# Sales and Marketing                                    0
# Server Administration                                  1
# Service Desk                                          22
# Web Conferencing                                       0
# WebEx                                                  0
#
# col_0                            Enterprise Application Service  \
# ActualService
# Application Development Service                               0
# Audio Conferencing                                            0
# BitLocker                                                     0
# Business Analytics Service                                    0
# Communications Services                                       0
# Data Service                                                  0
# Desktop Service                                               0
# Domain Migration                                              0
# Email Service                                                 0
# Employee Administration                                       0
# Enterprise Application Service                                0
# Facilities Management                                         0
# Financial Service                                             0
# Global DevOps                                                 0
# IT General Administration                                     0
# Integration Services                                          0
# Ivanti 100%                                                   0
# Licensing Portal                                              0
# Mail Service                                                  0
# Mobile Communication                                          0
# Network Service                                               0
# OKTA                                                          0
# OSUI                                                          0
# Printing Service                                              0
# Sales and Marketing                                           0
# Server Administration                                         0
# Service Desk                                                  1
# Web Conferencing                                              0
# WebEx                                                         0
#
# col_0                            Facilities Management  ...    \
# ActualService                                           ...
# Application Development Service                      0  ...
# Audio Conferencing                                   0  ...
# BitLocker                                            0  ...
# Business Analytics Service                           0  ...
# Communications Services                              0  ...
# Data Service                                         0  ...
# Desktop Service                                      0  ...
# Domain Migration                                     0  ...
# Email Service                                        0  ...
# Employee Administration                              0  ...
# Enterprise Application Service                       0  ...
# Facilities Management                                2  ...
# Financial Service                                    0  ...
# Global DevOps                                        0  ...
# IT General Administration                            1  ...
# Integration Services                                 0  ...
# Ivanti 100%                                          0  ...
# Licensing Portal                                     0  ...
# Mail Service                                         0  ...
# Mobile Communication                                 0  ...
# Network Service                                      0  ...
# OKTA                                                 0  ...
# OSUI                                                 0  ...
# Printing Service                                     0  ...
# Sales and Marketing                                  0  ...
# Server Administration                                0  ...
# Service Desk                                         1  ...
# Web Conferencing                                     0  ...
# WebEx                                                0  ...
#
# col_0                            Mobile Communication  Network Service  OKTA  \
# ActualService
# Application Development Service                     0                1     0
# Audio Conferencing                                  0                0     0
# BitLocker                                           0                0     0
# Business Analytics Service                          0                0     0
# Communications Services                             0                1     0
# Data Service                                        0                0     0
# Desktop Service                                     0                0     0
# Domain Migration                                    0                0     0
# Email Service                                       0                0     0
# Employee Administration                             0                0     0
# Enterprise Application Service                      0                0     0
# Facilities Management                               0                0     0
# Financial Service                                   0                0     0
# Global DevOps                                       0                1     0
# IT General Administration                           0                1     0
# Integration Services                                0                0     0
# Ivanti 100%                                         0                0     0
# Licensing Portal                                    0                0     0
# Mail Service                                        0                0     0
# Mobile Communication                                6                0     0
# Network Service                                     1               12     0
# OKTA                                                0                0     1
# OSUI                                                0                0     0
# Printing Service                                    0                0     0
# Sales and Marketing                                 0                0     0
# Server Administration                               2                4     0
# Service Desk                                        1               13     7
# Web Conferencing                                    0                0     0
# WebEx                                               0                0     0
#
# col_0                            OSUI  Printing Service  Sales and Marketing  \
# ActualService
# Application Development Service     1                 0                    2
# Audio Conferencing                  0                 0                    0
# BitLocker                           0                 0                    0
# Business Analytics Service          0                 0                    0
# Communications Services             0                 0                    0
# Data Service                        0                 0                    0
# Desktop Service                     0                 0                    0
# Domain Migration                    0                 0                    0
# Email Service                       0                 0                    0
# Employee Administration             0                 0                    0
# Enterprise Application Service      0                 0                    0
# Facilities Management               0                 0                    0
# Financial Service                   0                 0                    0
# Global DevOps                       0                 0                    0
# IT General Administration           0                 1                    0
# Integration Services                0                 0                    0
# Ivanti 100%                         0                 0                    0
# Licensing Portal                    0                 0                    0
# Mail Service                        0                 0                    0
# Mobile Communication                0                 0                    0
# Network Service                     0                 0                    0
# OKTA                                0                 1                    0
# OSUI                                6                 0                    0
# Printing Service                    0                 1                    0
# Sales and Marketing                 0                 0                   30
# Server Administration               0                 0                    0
# Service Desk                        4                 2                   10
# Web Conferencing                    0                 0                    0
# WebEx                               0                 0                    0
#
# col_0                            Server Administration  Service Desk  \
# ActualService
# Application Development Service                      5           205
# Audio Conferencing                                   0             2
# BitLocker                                            0            13
# Business Analytics Service                           0            10
# Communications Services                              1            63
# Data Service                                         2            11
# Desktop Service                                      1           161
# Domain Migration                                     3            10
# Email Service                                        1           110
# Employee Administration                              1            42
# Enterprise Application Service                       1            55
# Facilities Management                                0            10
# Financial Service                                    0             3
# Global DevOps                                        4            36
# IT General Administration                           27           149
# Integration Services                                 0             4
# Ivanti 100%                                          0            34
# Licensing Portal                                     1            14
# Mail Service                                         0            41
# Mobile Communication                                 0            17
# Network Service                                     13            87
# OKTA                                                 0            31
# OSUI                                                 0             1
# Printing Service                                     0             9
# Sales and Marketing                                  0            12
# Server Administration                              107           152
# Service Desk                                        88          3735
# Web Conferencing                                     0            30
# WebEx                                                0            19
#
# col_0                            Web Conferencing  WebEx
# ActualService
# Application Development Service                 0      0
# Audio Conferencing                              0      0
# BitLocker                                       0      0
# Business Analytics Service                      0      0
# Communications Services                         0      0
# Data Service                                    0      0
# Desktop Service                                 0      0
# Domain Migration                                0      0
# Email Service                                   0      0
# Employee Administration                         0      0
# Enterprise Application Service                  0      0
# Facilities Management                           0      0
# Financial Service                               0      0
# Global DevOps                                   0      0
# IT General Administration                       0      0
# Integration Services                            0      0
# Ivanti 100%                                     0      0
# Licensing Portal                                0      0
# Mail Service                                    0      0
# Mobile Communication                            0      0
# Network Service                                 0      0
# OKTA                                            0      0
# OSUI                                            0      0
# Printing Service                                0      0
# Sales and Marketing                             0      0
# Server Administration                           0      0
# Service Desk                                    1      1
# Web Conferencing                                2      0
# WebEx                                           0      1
#
# [29 rows x 25 columns]

# %%
train_df[train_df["ActualService"] == "Desktop Service"]
# Out:
#                                               train_text  \
# 15661  deleted history automatically closed cannot lo...
# 26111  in dsm i see you have this laptop cal and i am...
# 16087  called korinna and all is working again after ...
# 4880   i am closing this ticket as you indicated yest...
# 18720  conformed working closing case on andys approv...
# 1567   issue resolved since second restart and furthe...
# 17466  skype is working for michael automatically clo...
# 13098  jason can now logon without the sfb prompting ...
# 11251  signed out and signed back in to office accoun...
# 17514  issues confirmed caused by the latest esr rele...
# 17028  verified with you and didnt find anything wron...
# 27831  he was able to work with adam to rebuild the o...
# 15523  login change to motivosity seems to have occur...
# 10577  added davids machine to a group with av police...
# 30779  battery scheduled for delivery early next week...
# 8375   laptop was rebuilt to windows via dsm thanks r...
# 26852  onetime issue caused by registering to incorre...
# 28508  windows was reactivated with a new license aut...
# 19885  issue has been resolved site has been added in...
# 2410   reset users appsense com domain account passwo...
# 30987  salesforce agent and incontact softphone use t...
# 16220  got alexis to try the cached local password fo...
# 24646  lor automatically closed mac slower with av i ...
# 13884  printer double page printing resolved kind reg...
# 2961   released pr and converted to po automatically ...
# 31082  crpolpieniny phone is broken temporary replace...
# 27226  completed automatically closed laptop to br re...
# 29819  hi jamessince i did not receive any response t...
# 30122  laptop will be reimaged at a time convenient f...
# 24592  installed laptop and cached the shared mailbox...
# ...                                                  ...
# 25202  i deployed cisco anyconnect client to ellas co...
# 20442  through swapping the hdds between the two work...
# 14875  hey martinplease go ahead and order the upgrad...
# 23076  replaced with new one automatically closed new...
# 27666  computer matrix has been replaced by lenovo su...
# 1520   installed patch re installed emss all working ...
# 16972  resolved by calling from desk phone with prefi...
# 17062  issues with account cached information automat...
# 21248  reboot fixed automatically closed re vmware co...
# 25125  modified chrome folder permissions by followin...
# 2267   after recent discussions in the it department ...
# 29044  new headset has been provided automatically cl...
# 20039  incident closed after closing outlook and rebo...
# 10969  updated wifi driver from dell fixed the issue ...
# 23153  verified if all options are properly set up in...
# 2429   picture update worked for roland automatically...
# 13512  all sorted deleting via webex automatically cl...
# 21457  switched to another displayport automatically ...
# 10449  updated video driver automatically closed corr...
# 30086  prompt resolutie details automatically closed ...
# 26763  hi paulplease find all dates listed below paul...
# 17617  uninstalled and reinstalled the emss client au...
# 1919   usb adapter has been provided for jabra headse...
# 19982  reset password for users changed onetime passw...
# 5534   we have fixed the space issue for now but it n...
# 11628  hi christian im afraid that we cannot process ...
# 27447  screen repairedresolving case automatically cl...
# 5575   fixed by system repair started from bootable u...
# 16549  seemed that both brian and i were assisting yo...
# 17276  we have reset your password automatically clos...
#
#                                                 val_text    ActualService
# 15661  cannot login to myheatconnect com i get an sso...  Desktop Service
# 26111  my admin username and password for my machine ...  Desktop Service
# 16087  fw wifi functionality? it seems dsm disabled a...  Desktop Service
# 4880   onedrive migration in the instructions you sen...  Desktop Service
# 18720  bios password for my machine is it possible fo...  Desktop Service
# 1567   start menu not working installed some windows ...  Desktop Service
# 17466  i cannot log in or get skpe to work besides sk...  Desktop Service
# 13098  unable to log in to lync im unable to login in...  Desktop Service
# 11251  office says its not activated some functionali...  Desktop Service
# 17514  machine performance the machine was upgraded w...  Desktop Service
# 17028  laptop battery my battery will leak power and ...  Desktop Service
# 27831  bogus email wiped my outlook i got a bogus ema...  Desktop Service
# 15523  i cant login to motivosity via okta neither ca...  Desktop Service
# 10577  need av on my laptop ive had a new laptop for ...  Desktop Service
# 30779  my own hp latop my laptop during recent days d...  Desktop Service
# 8375   laptop rebuilt im on holidays from sept th for...  Desktop Service
# 26852  startup error windows script host error during...  Desktop Service
# 28508  windows license is about to expire windows exp...  Desktop Service
# 19885  not registed with sip registrar im unable to c...  Desktop Service
# 2410   expired password in appsense domain my passwor...  Desktop Service
# 30987  case closed without any information i opened a...  Desktop Service
# 16220  impossible to connect to sfdc we cant log you ...  Desktop Service
# 24646  mac slower with av i recently had my av update...  Desktop Service
# 13884  printer in support area printing jobs multiple...  Desktop Service
# 2961   pr please release this pr to generate a po in sap  Desktop Service
# 31082  phones in meeting rooms phones in two meeting ...  Desktop Service
# 27226  laptop to br reimaged as discused with jarosaw...  Desktop Service
# 29819  kaspersky av agent killing my mac kaspersky av...  Desktop Service
# 30122  microsoft cant install important security upda...  Desktop Service
# 24592  new laptop setup and outlook maibox caching ne...  Desktop Service
# ...                                                  ...              ...
# 25202  installation and access to cisco vpn client ca...  Desktop Service
# 20442  dell workstation lost the second hdd dell work...  Desktop Service
# 14875  visual assist x upgrade for vs we need to upgr...  Desktop Service
# 23076  new wireless keyboard and mouse kit is broken ...  Desktop Service
# 27666  laptops display blinks laptops display blinks ...  Desktop Service
# 1520   emss agent not working install wannacry patch ...  Desktop Service
# 16972  unable to call specific phone numbers need to ...  Desktop Service
# 17062  skype for business issues issues with skype fo...  Desktop Service
# 21248  re vmware connectivity issue i cannot access m...  Desktop Service
# 25125  chrome doesnt open on macbook chrome has just ...  Desktop Service
# 2267   getting error trying to install heat software ...  Desktop Service
# 29044  need new headset my jabra link headset doesnt ...  Desktop Service
# 20039  cannot sign into skype working from home i hav...  Desktop Service
# 10969  please call asap out of town computer says loc...  Desktop Service
# 23153  cant log in to incontact sf agent cant log in ...  Desktop Service
# 2429   aw service request waiting for more informatio...  Desktop Service
# 13512  cannot delete a recurrent meeting i have a mee...  Desktop Service
# 21457    one monitor doesnt work one monitor doesnt work  Desktop Service
# 10449            corrupt video from hdmi output as above  Desktop Service
# 30086  cypher access and instalation could you please...  Desktop Service
# 26763  laptop refresh due dates please would you supp...  Desktop Service
# 17617  emss agent is out of syncgreyed out on the pre...  Desktop Service
# 1919   my plantronics usb headset snapped i was exten...  Desktop Service
# 19982  users cant log in to incontact agent when domi...  Desktop Service
# 5534   cannot start vapps since today screenshot atta...  Desktop Service
# 11628  lightning vga adapter we need a lightningvga a...  Desktop Service
# 27447  screen broken in laptop poll when i was workin...  Desktop Service
# 5575   fwpkclnt sys boot up error after reboot comput...  Desktop Service
# 16549  password for cam i need to install an update f...  Desktop Service
# 17276  patty morins network pw needs to be reset plea...  Desktop Service
#
# [686 rows x 3 columns]

# %%
old_model = pd.read_csv("it_dec18.csv")
old_model.shape
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (17,80,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (31755, 132)

# %%
old_model = old_model[~(pd.isnull(old_model["DIUpdateServicePrediction"]))]
old_model["DIUpdateServicePrediction"] = old_model["DIUpdateServicePrediction"].str.strip()
print(old_model.shape)
# old_model["DIUpdateServicePrediction"].value_counts()

e = pd.crosstab(old_model["ActualService"],old_model["DIUpdateServicePrediction"], margins=True)
e.to_csv("temp1.csv")

a = classification_report(old_model["ActualService"],old_model["DIUpdateServicePrediction"])
print(a)
# Out:
# (5562, 132)

# %%
old_service = old_model["DIUpdateServicePrediction"].unique()

new_service = old_model["ActualService"].unique()

np.setdiff1d(old_model["ActualService"], old_model["DIUpdateServicePrediction"])

# %%
old_model = old_model[~(pd.isnull(old_model["DIUpdateTeamPrediction"]))]
old_model["DIUpdateTeamPrediction"] = old_model["DIUpdateTeamPrediction"].str.strip()
print(old_model.shape)

e = pd.crosstab(old_model["OwnerTeam"],old_model["DIUpdateTeamPrediction"], margins=True)
e.to_csv("Team.csv")

a = classification_report(old_model["OwnerTeam"],old_model["DIUpdateTeamPrediction"])
print(a)
# Out:
# (5562, 132)
#                                      precision    recall  f1-score   support
#
#             Application Development       0.47      0.59      0.52       201
#               Business Applications       0.62      0.79      0.70       549
#               Business Intelligence       0.33      0.47      0.39        15
#                    Business Support       0.09      0.12      0.10        33
#                              CS-Ops       0.00      0.00      0.00       146
#                           Cloud Ops       0.00      0.00      0.00         1
#                         DevOps/100%       0.00      0.00      0.00         0
#             Facilities / Operations       1.00      0.17      0.29        12
#              Finance: SKU Approvals       0.00      0.00      0.00         2
#                       Global DevOps       1.00      0.01      0.01       307
#              Infrastructure Support       0.42      0.56      0.48       674
# Opportunity Team - Customer Success       0.00      0.00      0.00         2
#     Order Management: SKU Approvals       0.00      0.00      0.00        14
#                   Pricing Committee       0.00      0.00      0.00         4
#      Professional Services Americas       0.00      0.00      0.00         1
#                         SAP-WorkDay       0.79      0.61      0.69       198
#                   SalesOps Americas       0.00      0.00      0.00       232
#                     SalesOps Global       0.00      0.00      0.00         1
#                SalesOps InsideSales       0.00      0.00      0.00         1
#                            Security       0.80      0.02      0.04       379
#                        Service Desk       0.74      0.89      0.81      2766
#                             Shavlik       0.00      0.00      0.00         7
#                     Web Development       0.86      0.86      0.86        14
#                       Web Marketing       0.50      0.33      0.40         3
#
#                         avg / total       0.64      0.64      0.58      5562
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
old_service = old_model["DIUpdateTeamPrediction"].unique()

new_service = old_model["OwnerTeam"].unique()

print(np.setdiff1d(old_model["OwnerTeam"], old_model["DIUpdateTeamPrediction"]))
print( np.setdiff1d(old_model["DIUpdateTeamPrediction"],old_model["OwnerTeam"]))
# Out:
# ['CS-Ops' 'Cloud Ops' 'Finance: SKU Approvals'
#  'Opportunity Team - Customer Success' 'Order Management: SKU Approvals'
#  'Pricing Committee' 'Professional Services Americas' 'SalesOps Americas'
#  'SalesOps Global' 'SalesOps InsideSales' 'Shavlik']
# ['DevOps/100%']

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
for label in dataset.columns:
    dataset[label] = LabelEncoder().fit(dataset[label]).transform(dataset[label])
    
X = dataset.drop(['target'],axis=1)
Y = dataset['target']
#model = DecisionTreeClassifier(criterion='entropy',max_depth=1)
#AdaBoost = AdaBoostClassifier(base_estimator= model,n_estimators=400,learning_rate=1)
AdaBoost = AdaBoostClassifier(n_estimators=400,learning_rate=1,algorithm='SAMME')
AdaBoost.fit(X,Y)
prediction = AdaBoost.score(X,Y)
print('The accuracy is: ',prediction*100,'%')
