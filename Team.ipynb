# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier,RidgeClassifier,PassiveAggressiveClassifier
import pickle
from sklearn.metrics import precision_recall_fscore_support,accuracy_score, classification_report
from sklearn.calibration import CalibratedClassifierCV,_CalibratedClassifier
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from pprint import pprint
from time import time
import logging
from sklearn.decomposition import TruncatedSVD
import os
import psutil
import resource

# %% [markdown]
# # Define Constants

# %%
data_filepath = "it_dec18_mod.csv"

label_freq_threshold = 10

# requirement for new data

cols = ['Resolution','Subject','body','OwnerTeam']
training_cols = ['Resolution','Subject','body']
runtime_cols = ['Subject','body']
target_col = ['OwnerTeam']

#internal declaration

train_col_name = "train_text"
val_col_name = "val_text"

# %% [markdown]
# # Data Preprocessing

# %%
def remove_and_dedup_punctuation_numbers(text): 
    result = re.sub('<.*?>', '', text.replace("(AutoClosed)","").replace("\n","").replace("\r","")\
                    .replace("&nbsp;","").replace("***",""))
    result = result.replace('[\w\d\.-]+@[\w\d\.-]+',' ').replace(
    '\d+', ' ').replace('_+', ' ').replace('+', ' ').replace(
    '.', ' ').replace('^https?:\/\/.*[\r\n]*', '').replace('[^\w]',' ').lower()
    result = re.sub (r'([^a-zA-Z\s.?!])', '', result)
    result = re.sub(r"([" + re.escape(string.punctuation) + r"])\1+", r"\1", result)
    result = re.sub( '\s+', ' ', result ).strip()
    return result


def drop_nan(df,training_cols,target_col):
    print("method drop_nan started:\n")
    print("number of records before processing: ",df.__len__())
    df1 = df[training_cols].dropna(how="all")
    indices_1 = df1.index
    df2 = df[target_col].dropna(how="all")
    indices_2 = df2.index
    indices_final = list(set.intersection(set(indices_1),set(indices_2)))
    return_df = df.iloc[indices_final][training_cols+target_col]
    print("number of records after processing: ",return_df.__len__())
    print("NaN value Present? ",return_df[target_col+training_cols].isnull().values.any())
    return_df.fillna("", inplace=True)
    print("NaN value Present? ",return_df[target_col+training_cols].isnull().values.any())
    print("\nmethod drop_nan ended.\n\n")
    return return_df

def create_and_clean_train_test_target_column(df):
    print("method create_and_clean_train_test_target_column started:\n")
    df[train_col_name] = df[training_cols].apply(lambda x: " ".join(x), axis=1)
    df[train_col_name] = df[train_col_name].map(remove_and_dedup_punctuation_numbers)
    df[val_col_name] = df[runtime_cols].apply(lambda x: " ".join(x), axis=1)
    df[val_col_name] = df[val_col_name].map(remove_and_dedup_punctuation_numbers)
    print("\nmethod create_and_clean_train_test_target_column ended.\n\n")
    return df[[train_col_name,val_col_name]+target_col]

# %% [markdown]
# # Modeling

# %%
def get_tfidf_parameters():
    param =  {
        'tfidf__lowercase':(True,),
        'tfidf__stop_words':('english',),
        'tfidf__max_df': (0.90,0.85),
        'tfidf__min_df': (2,5),
        'tfidf__sublinear_tf': (True,),
        'tfidf__ngram_range': ((1,3),)
    }
    return param

def get_SGDClassifier_parameters():
    param = {
        'clf__alpha': (0.0001,),
        'clf__penalty': ('elasticnet',),
        'clf__loss': ('hinge',),
        'clf__max_iter': (20,)
    }
    return param

def get_RidgeClassifier_parameters():
    param = {
        'clf__tol': (1e-2,),
        'clf__solver': ('sag',)
    }
    return param


def get_LinearSVC_parameters():
    param = {
        'clf__penalty': ('l2',),
        'clf__loss': ('hinge',),
        'clf__tol': (1e-4,),
        'clf__max_iter': (10,),
        'clf__multi_class': ('ovr',),
        'clf__class_weight': ('balanced',)
    }
    return param


def get_RandomForestClassifier_parameters():
    param = {
        'clf__n_estimators': (90,),
        'clf__max_depth': (11,),
        'clf__min_samples_leaf': (8,)
    }
    return param

def get_LogisticRegression_parameters():
    param = {
        'clf__multi_class': ('ovr',),
    }
    return param

def get_PassiveAggressiveClassifier_parameters():
    param = {
        'clf__max_iter': (50,),
    }
    return param

def print_model_stat(grid_search,pipeline,parameters,clfname):
    print("Performing grid search for ",clfname," ...")
    print("pipeline:", [name for name, _ in pipeline.steps])
    print("parameters:")
    pprint(parameters)    
    print()
    print("Best score: %0.3f" % grid_search.best_score_)
    print()
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
        
def get_clf_and_parameter(clfname):
    if clfname == "SGDClassifier":
        clf = SGDClassifier()
        clf_param = get_SGDClassifier_parameters()
    elif clfname == "RidgeClassifier":
        clf = RidgeClassifier()
        clf_param = get_RidgeClassifier_parameters()
    elif clfname == "LinearSVC":
        clf = LinearSVC()
        clf_param = get_LinearSVC_parameters()
    elif clfname == "RandomForestClassifier":
        clf = RandomForestClassifier()
        clf_param = get_RandomForestClassifier_parameters()
    elif clfname == "LogisticRegression":
        clf = LogisticRegression()
        clf_param = get_LogisticRegression_parameters()
    elif clfname == "PassiveAggressiveClassifier":
        clf = PassiveAggressiveClassifier()
        clf_param = get_PassiveAggressiveClassifier_parameters()
    else:
        raise BaseException("Unknown Classifier.")
        
    return clf,clf_param
        
def train_gridsearch_classifier_pipeline(train_df,clfname,val_col_name,target_col,score = 'accuracy'):
    
    clf,clf_param = get_clf_and_parameter(clfname)
        
    pipeline = Pipeline([
        ('tfidf', TfidfVectorizer()),
        ('clf', clf)])
    
    tfidf_param = get_tfidf_parameters()
    
    parameters = {**tfidf_param, **clf_param}
    
    grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1,scoring=score)
    X = train_df[val_col_name].as_matrix()
    Y = train_df[target_col].as_matrix().ravel()
    grid_search.fit(X, Y)
    
    print_model_stat(grid_search,pipeline,parameters,clfname)
    
    #https://github.com/scikit-learn/scikit-learn/issues/8710
    calibrated_pipeline = _CalibratedClassifier(base_estimator=grid_search.best_estimator_, method='isotonic')
    return calibrated_pipeline



class TeamPredictionModel(object):
    def __init__(self,best_model,best_acc,best_classifier_name):
        self.best_model = best_model
        self.best_cv_acc = best_acc
        self.best_classifier_name = best_classifier_name
    
    @classmethod
    def train(cls,df,target_col,train_col_name,val_col_name):
        target = df[target_col].as_matrix()
        train_df, test_df = train_test_split(df,test_size=0.2,stratify=target,random_state=0)
        
        classifier_names = [
                            "LogisticRegression",
                            "RandomForestClassifier",
                            "LinearSVC",
                            "SGDClassifier",
                            "RidgeClassifier",
                            "PassiveAggressiveClassifier"
                           ]
        classifiers = list()
        
        for classifier_name in classifier_names:
            classifier = train_gridsearch_classifier_pipeline(train_df,classifier_name,
                                                              val_col_name,target_col)
            classifiers.append(classifier)
                
        best_model = None
        best_cv_acc = -100
        best_classifier_name = None
        
        X = train_df[train_col_name].as_matrix()
        Y = train_df[target_col].as_matrix().ravel()
        
        for i,clf in enumerate(classifiers):
            
            clf.fit(X,Y)
            label_encoder = clf.label_encoder_
            Y_prob = clf.predict_proba(test_df[val_col_name])
            Y_index = np.argmax(Y_prob,axis=1)
            Y_index = Y_index.ravel()
            # https://github.com/scikit-learn/scikit-learn/issues/10449
            Y_pred = label_encoder.inverse_transform(Y_index)
            Y_test = test_df[target_col]
            cv_acc = accuracy_score(Y_test, Y_pred)
            if cv_acc > best_cv_acc:
                best_cv_acc = cv_acc
                best_model = clf
                best_classifier_name = classifier_names[i]
            print("Classifier Name : ",classifier_names[i])
            print("Validation Accuracy : ",cv_acc)
            
        X = df[train_col_name].as_matrix()
        Y = df[target_col].as_matrix().ravel()
            
        best_model.fit(X,Y)
        
        print("Best classifier Name : ",best_classifier_name)
        print("Best validation Accuracy : ",best_cv_acc)
            
        return TeamPredictionModel(best_model,best_cv_acc,best_classifier_name)


    
    def save(self,filepath):
        model_dict = {"model":self.best_model,
                      "validation_accuracy":self.best_cv_acc,
                      "model_name":self.best_classifier_name
                     }
        with open(filepath,"wb") as fp:
            pickle.dump(model_dict,fp,pickle.HIGHEST_PROTOCOL)

# %%
def preprocess_data(data_filepath):
    df = pd.read_csv(data_filepath,low_memory=False)
    truncated_df_null_removed = drop_nan(df,training_cols,target_col)
    df_train_test_target = create_and_clean_train_test_target_column(truncated_df_null_removed)
    df_cleaned = df_train_test_target.groupby(target_col).filter(lambda x: len(x) > label_freq_threshold)
    return df_cleaned
    
def train_and_save_model(df_cleaned,target_col,train_col_name,val_col_name):
    team_pred_model = TeamPredictionModel.train(df_cleaned,target_col,train_col_name,val_col_name)
    team_pred_model.save("./team_model.pkl")

# %%
def main():
    df_cleaned = preprocess_data(data_filepath)
    train_and_save_model(df_cleaned,target_col,train_col_name,val_col_name)

# %%
# %%time

if __name__ == "__main__":
    main()
# Out:
# method drop_nan started:
#
# number of records before processing:  31932
# number of records after processing:  31739
# NaN value Present?  True
# NaN value Present?  False
#
# method drop_nan ended.
#
#
# method create_and_clean_train_test_target_column started:
#
#
# method create_and_clean_train_test_target_column ended.
#
#
# Performing grid search for  LogisticRegression  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__multi_class': ('ovr',),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.731
#
# Best parameters set:
# 	clf__multi_class: 'ovr'
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 5
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  RandomForestClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__max_depth': (11,),
#  'clf__min_samples_leaf': (8,),
#  'clf__n_estimators': (90,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.585
#
# Best parameters set:
# 	clf__max_depth: 11
# 	clf__min_samples_leaf: 8
# 	clf__n_estimators: 90
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.85
# 	tfidf__min_df: 5
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  LinearSVC  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__class_weight': ('balanced',),
#  'clf__loss': ('hinge',),
#  'clf__max_iter': (10,),
#  'clf__multi_class': ('ovr',),
#  'clf__penalty': ('l2',),
#  'clf__tol': (0.0001,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.714
#
# Best parameters set:
# 	clf__class_weight: 'balanced'
# 	clf__loss: 'hinge'
# 	clf__max_iter: 10
# 	clf__multi_class: 'ovr'
# 	clf__penalty: 'l2'
# 	clf__tol: 0.0001
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.85
# 	tfidf__min_df: 2
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  SGDClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__alpha': (0.0001,),
#  'clf__loss': ('hinge',),
#  'clf__max_iter': (20,),
#  'clf__penalty': ('elasticnet',),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.753
#
# Best parameters set:
# 	clf__alpha: 0.0001
# 	clf__loss: 'hinge'
# 	clf__max_iter: 20
# 	clf__penalty: 'elasticnet'
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 5
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  RidgeClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__solver': ('sag',),
#  'clf__tol': (0.01,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.762
#
# Best parameters set:
# 	clf__solver: 'sag'
# 	clf__tol: 0.01
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 2
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# Performing grid search for  PassiveAggressiveClassifier  ...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__max_iter': (50,),
#  'tfidf__lowercase': (True,),
#  'tfidf__max_df': (0.9, 0.85),
#  'tfidf__min_df': (2, 5),
#  'tfidf__ngram_range': ((1, 3),),
#  'tfidf__stop_words': ('english',),
#  'tfidf__sublinear_tf': (True,)}
#
# Best score: 0.739
#
# Best parameters set:
# 	clf__max_iter: 50
# 	tfidf__lowercase: True
# 	tfidf__max_df: 0.9
# 	tfidf__min_df: 2
# 	tfidf__ngram_range: (1, 3)
# 	tfidf__stop_words: 'english'
# 	tfidf__sublinear_tf: True
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  LogisticRegression
# Validation Accuracy :  0.7661620939766635
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  RandomForestClassifier
# Validation Accuracy :  0.6980447808262378
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  LinearSVC
# Validation Accuracy :  0.7625354777672658
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  SGDClassifier
# Validation Accuracy :  0.7737306843267108
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  RidgeClassifier
# Validation Accuracy :  0.7732576474298328
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Classifier Name :  PassiveAggressiveClassifier
# Validation Accuracy :  0.7385682749921161
# Best classifier Name :  SGDClassifier
# Best validation Accuracy :  0.7737306843267108
# CPU times: user 1min 28s, sys: 2.97 s, total: 1min 31s
# Wall time: 4min 48s

# %%
model_dict = joblib.load("team_model.pkl")

# %%
clf = model_dict["model"]
df_cleaned = preprocess_data(data_filepath)
target = df_cleaned[target_col].as_matrix()
train_df, test_df = train_test_split(df_cleaned,test_size=0.2,stratify=target,random_state=0)
label_encoder = clf.label_encoder_
Y_prob = clf.predict_proba(test_df[val_col_name])
Y_index = np.argmax(Y_prob,axis=1)
Y_index = Y_index.ravel()
# https://github.com/scikit-learn/scikit-learn/issues/10449
Y_pred = label_encoder.inverse_transform(Y_index)
Y_test = test_df[target_col]
# Out:
# method drop_nan started:
#
# number of records before processing:  31932
# number of records after processing:  31739
# NaN value Present?  True
# NaN value Present?  False
#
# method drop_nan ended.
#
#
# method create_and_clean_train_test_target_column started:
#
#
# method create_and_clean_train_test_target_column ended.
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.771838536739199

# %%
classification = classification_report(Y_test, Y_pred)
print(classification)
# Out:
#                                  precision    recall  f1-score   support
#
#         Application Development       0.73      0.77      0.75       639
#           Business Applications       0.77      0.73      0.75       438
#           Business Intelligence       0.65      0.37      0.47        35
#                Business Support       0.15      0.07      0.09        45
#                          CS-Ops       0.90      0.66      0.76        29
#                     DevOps/100%       0.72      0.61      0.66       133
#         Facilities / Operations       0.00      0.00      0.00        10
#                              IT       0.00      0.00      0.00        24
#          Infrastructure Support       0.62      0.50      0.55      1010
# Order Management: SKU Approvals       1.00      0.17      0.29         6
#                     SAP-WorkDay       0.57      0.71      0.63       122
#               SalesOps Americas       0.91      0.54      0.67        54
#                        Security       0.96      0.77      0.85        98
#                    Service Desk       0.82      0.89      0.85      3679
#                         Shavlik       0.50      0.33      0.40         3
#                 Web Development       0.00      0.00      0.00        13
#                   Web Marketing       0.00      0.00      0.00         4
#
#                     avg / total       0.76      0.77      0.76      6342
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
conf = pd.crosstab(Y_test.OwnerTeam, Y_pred)

# %%
conf
# Out:
# col_0                            Application Development  \
# OwnerTeam
# Application Development                              483
# Business Applications                                 32
# Business Intelligence                                  3
# Business Support                                       1
# CS-Ops                                                 0
# DevOps/100%                                            1
# Facilities / Operations                                0
# IT                                                     1
# Infrastructure Support                                10
# Order Management: SKU Approvals                        5
# SAP-WorkDay                                           16
# SalesOps Americas                                      0
# Security                                               0
# Service Desk                                          81
# Shavlik                                                0
# Web Development                                        3
# Web Marketing                                          0
#
# col_0                            Business Applications  Business Intelligence  \
# OwnerTeam
# Application Development                             34                      0
# Business Applications                              329                      0
# Business Intelligence                                2                     13
# Business Support                                    12                      0
# CS-Ops                                               4                      1
# DevOps/100%                                          0                      0
# Facilities / Operations                              0                      0
# IT                                                   0                      0
# Infrastructure Support                               4                      0
# Order Management: SKU Approvals                      0                      0
# SAP-WorkDay                                          4                      0
# SalesOps Americas                                   11                      0
# Security                                             0                      0
# Service Desk                                        27                      1
# Shavlik                                              0                      0
# Web Development                                      0                      0
# Web Marketing                                        0                      0
#
# col_0                            Business Support  CS-Ops  DevOps/100%  \
# OwnerTeam
# Application Development                         2       0            0
# Business Applications                           4       1            0
# Business Intelligence                           0       0            0
# Business Support                                6       0            0
# CS-Ops                                          0      20            0
# DevOps/100%                                     0       0           79
# Facilities / Operations                         0       0            0
# IT                                              0       0            2
# Infrastructure Support                          0       0            2
# Order Management: SKU Approvals                 0       0            0
# SAP-WorkDay                                     0       0            0
# SalesOps Americas                               1       0            0
# Security                                        0       0            0
# Service Desk                                    7       1           20
# Shavlik                                         0       0            0
# Web Development                                 0       0            0
# Web Marketing                                   0       0            0
#
# col_0                            Facilities / Operations  IT  \
# OwnerTeam
# Application Development                                0   0
# Business Applications                                  0   0
# Business Intelligence                                  0   0
# Business Support                                       0   0
# CS-Ops                                                 0   0
# DevOps/100%                                            0   0
# Facilities / Operations                                1   0
# IT                                                     0   0
# Infrastructure Support                                 0   0
# Order Management: SKU Approvals                        0   0
# SAP-WorkDay                                            0   0
# SalesOps Americas                                      0   0
# Security                                               0   0
# Service Desk                                           0   4
# Shavlik                                                0   0
# Web Development                                        0   0
# Web Marketing                                          0   0
#
# col_0                            Infrastructure Support  \
# OwnerTeam
# Application Development                              30
# Business Applications                                 2
# Business Intelligence                                 4
# Business Support                                      6
# CS-Ops                                                0
# DevOps/100%                                          31
# Facilities / Operations                               1
# IT                                                    1
# Infrastructure Support                              575
# Order Management: SKU Approvals                       0
# SAP-WorkDay                                           0
# SalesOps Americas                                     0
# Security                                              1
# Service Desk                                        286
# Shavlik                                               1
# Web Development                                       0
# Web Marketing                                         1
#
# col_0                            Order Management: SKU Approvals  SAP-WorkDay  \
# OwnerTeam
# Application Development                                        0            9
# Business Applications                                          0           19
# Business Intelligence                                          0            7
# Business Support                                               0            0
# CS-Ops                                                         0            0
# DevOps/100%                                                    0            0
# Facilities / Operations                                        0            0
# IT                                                             0            0
# Infrastructure Support                                         0            3
# Order Management: SKU Approvals                                1            0
# SAP-WorkDay                                                    0           86
# SalesOps Americas                                              0            0
# Security                                                       0            0
# Service Desk                                                   1           19
# Shavlik                                                        0            0
# Web Development                                                0            0
# Web Marketing                                                  0            0
#
# col_0                            SalesOps Americas  Security  Service Desk  \
# OwnerTeam
# Application Development                          0         0            80
# Business Applications                            3         0            48
# Business Intelligence                            0         0             6
# Business Support                                 0         0            20
# CS-Ops                                           0         0             4
# DevOps/100%                                      0         1            21
# Facilities / Operations                          0         0             8
# IT                                               0         0            20
# Infrastructure Support                           1         4           410
# Order Management: SKU Approvals                  0         0             0
# SAP-WorkDay                                      0         0            16
# SalesOps Americas                               37         0             5
# Security                                         0        84            13
# Service Desk                                     1         3          3224
# Shavlik                                          0         0             1
# Web Development                                  0         0             8
# Web Marketing                                    0         0             3
#
# col_0                            Shavlik  Web Development  Web Marketing
# OwnerTeam
# Application Development                0                1              0
# Business Applications                  0                0              0
# Business Intelligence                  0                0              0
# Business Support                       0                0              0
# CS-Ops                                 0                0              0
# DevOps/100%                            0                0              0
# Facilities / Operations                0                0              0
# IT                                     0                0              0
# Infrastructure Support                 1                0              0
# Order Management: SKU Approvals        0                0              0
# SAP-WorkDay                            0                0              0
# SalesOps Americas                      0                0              0
# Security                               0                0              0
# Service Desk                           0                3              1
# Shavlik                                1                0              0
# Web Development                        0                2              0
# Web Marketing                          0                0              0

# %%
train_df[train_df["OwnerTeam"] == "IT"]
# Out:
#                                               train_text  \
# 1389   assigned a resharper license for bartosz sent ...
# 9104   barbie discovered the issue automatically clos...
# 1201   closed at customer request automatically close...
# 7368   completed automatically closed network cable l...
# 7080   hey andyif the customer leaves a voicemail the...
# 4291   your key card has been disabled when you are b...
# 4511   changed the email address to it incidents in q...
# 6860   hi oliviaalans details have been added to the ...
# 8289   new door access card created automatically clo...
# 15204  crash dump sugested graphics drivers updated i...
# 9485   resolved automatically closed add clock to pho...
# 11070  catching up on ticket resolutions circuit upgr...
# 11930  completed automatically closed conference room...
# 3801   the ipad is on its way to vietnam you can trac...
# 10437  this has been resolved automatically closed ne...
# 7410   webex installed automatically closed eyre squa...
# 17055  created mb and assigned permissions to send on...
# 7932   your frontrange webex com site has temporarily...
# 15587  the issue was resolved late last night sunday ...
# 14152  advised okta site not live until th raised sep...
# 9996   sorted ciaranclosing ticket automatically clos...
# 6645   hi ericthis issue was resolved about hour ago ...
# 6295   requested link be emailed to me to test never ...
# 10762  hi jorritwe have now provided your access via ...
# 7173   complete automatically closed report in ssrs i...
# 10241  machine allocated to niall closing incident au...
# 434    vpn issue was fixed debbie had a few other iss...
# 16632  just a test automatically closed im broke this...
# 16203  reset all multifacter devices automatically cl...
# 3794   no response from matt closing incidentpaul aut...
# ...                                                  ...
# 1891   automatically closed due to lack of response f...
# 12703  closed automatically closed cannot transfer ca...
# 16492  had to manually create okta profile then impor...
# 7789   numbers have been ported over or are no longer...
# 16647  unlocked account automatically closed locked o...
# 15925  confirmed service is up and running re prp ema...
# 16498  gave paul send as permission for contactgoldmi...
# 9951   door access added automatically closed access ...
# 7247   this has been resolved automatically closed so...
# 9210   completed automatically closed marie irwin out...
# 16025  everyones account hasnt been changed to ivanti...
# 16444  troy gave adam access to the file path adam ve...
# 17056  confirmed that anyone trying to access got the...
# 14987  hi naroeunthe expense report for deann has bee...
# 7663   hey suei have temporarily reenabled your old f...
# 2625   hi art the redirect web forward record pointin...
# 10469  kiko now has a test machine closing ticket aut...
# 2573   your webex and intercall accounts have been cr...
# 5467   completed fixed toolbar automatically closed i...
# 2214   glad to hear you were working again after rese...
# 34     gary started todaynew machine setup user up an...
# 30     issue has resolved itself closing per terri re...
# 8128   sent tim an iso of embedded windows via sftp a...
# 809    resolved automatically closed laptop for testi...
# 3831   pasword reset to heat!regardspaul automaticall...
# 7520   added to the itglobalappsteam dl if you have a...
# 7338   motherboard has been replaced automatically cl...
# 238    granted send as lumension ar rights lumension ...
# 17373  encrypted with bitlocker successfully x drives...
# 6416   eric irestone looks after this mick and i see ...
#
#                                                 val_text OwnerTeam
# 1389   request for resharper license id like to reque...        IT
# 9104   support line south africa our partner in sa is...        IT
# 1201   folder corrupted by osiris virus we have a fil...        IT
# 7368   network cable lan looks like i have a dodgy ne...        IT
# 7080   fw voicemail from message id i received this e...        IT
# 4291   disable building access card i lost my access ...        IT
# 4511   password manager template update could you ple...        IT
# 6860   galway office mailing list can you please add ...        IT
# 8289   new swipe can i please request a new swipe min...        IT
# 15204  bsod on dock since friday john keeps getting a...        IT
# 9485   add clock to phones sorry paul but im not sure...        IT
# 11070  galway access to build servers the network spe...        IT
# 11930  conference room setup the rd conference room n...        IT
# 3801   need ipad air for s vietnam qa orders under he...        IT
# 10437  network drive mappings as you could see on pri...        IT
# 7410   eyre square meeting room could you please prov...        IT
# 17055  office account for automation emails we requir...        IT
# 7932   cannot cancel webex meetings since frontrange ...        IT
# 15587  heatsoftware com domain mailboxes not fetching...        IT
# 14152  can not log into community i am unable to logi...        IT
# 9996   upgrading sepa would it be possible to upgrade...        IT
# 6645                            gss iegsssql unreachable        IT
# 6295   new heatsoftware url link in webex does not wo...        IT
# 10762  cannot access dropbox business ive setup dropb...        IT
# 7173   report in ssrs isnt updating to get daily bill...        IT
# 10241  need a machine with a tpm enabled chip to perf...        IT
# 434    fw transitions of vpn i cant even get to a poi...        IT
# 16632                       im broke this is just a test        IT
# 16203  reset multifactor however phone is not powerin...        IT
# 3794   re confirmation you have changed your webex ac...        IT
# ...                                                  ...       ...
# 1891   german number option not directing to correct ...        IT
# 12703  cannot transfer calls to various extensions ca...        IT
# 16492  canlt log in to emails or okta account was pre...        IT
# 7789   telesphere apac numbers i was just told by my ...        IT
# 16647  locked out of account locked out of appsense a...        IT
# 15925  re prp email issues spam filter you only recei...        IT
# 16498  prp email i have access to the contactgoldmine...        IT
# 9951   access to qa lab room would you be able to add...        IT
# 7247   soft phone can someone help setup my soft phon...        IT
# 9210   marie irwin outlook can you please give elaine...        IT
# 16025  cant log into salesforce through okta receive ...        IT
# 16444                           re tick access to shares        IT
# 17056  can not access vpn trying to access vpn via ch...        IT
# 14987  expense report approval deann benn has expense...        IT
# 7663   need to be able to delete old webex recurring ...        IT
# 2625   need url redirects this is for michael jackson...        IT
# 10469  desktop required for virtual machines training...        IT
# 2573   webex account i need to have a webex account c...        IT
# 5467   ipcm login failed unable to take customer call...        IT
# 2214   ip phone is down again similar to events last ...        IT
# 34     new hire gary moore start date th october set ...        IT
# 30     re tick is the network slow or am i really rea...        IT
# 8128   new ticket win embedded tim is asking if we ha...        IT
# 809    laptop for testing i need a laptop to test blo...        IT
# 3831   lumension webex password reset lumension webex...        IT
# 7520   add me to itglobalappsteam dl im currently the...        IT
# 7338   laptop power failure my dell latitude e servic...        IT
# 238                                 lumension ar mailbox        IT
# 17373               encrypt drives encrypt laptop drives        IT
# 6416   jive issue? jive seems to be down its not just...        IT
#
# [96 rows x 3 columns]
